# %%
import pandas as pd
import numpy as np 
import seaborn as sns

# %%
df = pd.read_csv('AB_NYC_2019.csv')

# %%
df.shape
# Out:
# (48895, 16)

# %%
df.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
df.sample(10)
# Out:
#              id                                               name    host_id  \
# 28112  21935727           Designers' Brooklyn Loft – 2 bed, 2 bath    1341264
# 47215  35642402           1-Bedroom Sweet Spot in Carroll Gardens!    8093028
# 19561  15646864     Williamsburg / Greenpoint 1500 square foot apt    8712217
# 7437    5536560          Classy neighborhood, close to everything.     257479
# 24400  19643642  One stop to midtown Manhattan one stop to Broo...   20440843
# 6756    4840841                Quiet, Modern Gem in LES w balcony!    4244200
# 46394  35231663    Room in a Luxury Apartment + Gym + AC + Laundry   14332697
# 24320  19585955                     Quiet Full Bed, loft and couch    4471200
# 41552  32304108                          Carroll Gardens Cozy Nest  152114575
# 11746   9133278                       This Empty Nest is the Best!      25459
#
#        host_name neighbourhood_group       neighbourhood  latitude  longitude  \
# ...

# %%
df.isnull().sum()
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
df1 = df.copy()

# %% [markdown]
# ## Eliminating the entire row of the data set if there is any null values

# %%
df1.dropna(inplace = True) ## You need to put inplace if you want to make it permanent change

# %%
df1.isnull().sum()
# Out:
# id                                0
# name                              0
# host_id                           0
# host_name                         0
# neighbourhood_group               0
# neighbourhood                     0
# latitude                          0
# longitude                         0
# room_type                         0
# price                             0
# minimum_nights                    0
# number_of_reviews                 0
# last_review                       0
# reviews_per_month                 0
# calculated_host_listings_count    0
# availability_365                  0
# dtype: int64

# %%
df1.shape
# Out:
# (38821, 16)

# %%
df2 = df.copy()

# %%
df2.drop( 'host_id',inplace = True , axis = 1)

# %%
df2.isnull().sum() #host if has been eliminated
# Out:
# id                                    0
# name                                 16
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
df2.shape
# Out:
# (48895, 15)

# %% [markdown]
# ## Imputations

# %%
df3 = df.copy()

# %%
df3.shape
# Out:
# (48895, 16)

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
# ...

# %%
mean_value = df3['reviews_per_month'].mean()

# %%
mean_value
# Out:
# 1.3732214298586618

# %%
df3['reviews_per_month'].fillna(mean_value, inplace = True)

# %%
df3.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
mode_value = df3['last_review'].mode()

# %%
mode_value
# Out:
# 0    2019-06-23
# Name: last_review, dtype: object

# %%
df3['last_review'].fillna(df3['last_review'].value_counts().index[0], inplace = True)

# %%
df3.sample(10)
# Out:
#              id                                               name    host_id  \
# 28501  22099266                                 Aquamarine Bedroom  119669058
# 11984   9334228                 Cozy Studio in an Amazing Location    1423321
# 17146  13584889                            COMFORTABLE &  FRIENDLY   78218328
# 31851  24853655   Luxury 1BR close to Columbus Circle/Central Park  102351927
# 47595  35826493      NEW Modern Entire 2Bed Parkview Unforgettable  257647514
# 45750  34938410       (E) Private Queen Room LGA JFK Manhattan 15m  263053182
# 27512  21665632  SOHO LOFT: 2000sq ft renovated & centrally loc...   11242618
# 35695  28336933         West Village 5 BR Townhouse & Private Yard  126830432
# 18093  14165982                        Comfortable apartment in FH   19538448
# 4120    2652865                   Classic Upper West Side Getaway!    9951993
#
#       host_name neighbourhood_group       neighbourhood  latitude  longitude  \
# ...

# %%
df3.isnull().sum()
# Out:
# id                                 0
# name                              16
# host_id                            0
# host_name                         21
# neighbourhood_group                0
# neighbourhood                      0
# latitude                           0
# longitude                          0
# room_type                          0
# price                              0
# minimum_nights                     0
# number_of_reviews                  0
# last_review                        0
# reviews_per_month                  0
# calculated_host_listings_count     0
# availability_365                   0
# dtype: int64

# %%
df4 = df.copy()

# %%
df4.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
df4.shape
# Out:
# (48895, 16)

# %%
df4['last_review'].fillna('Not_reviewed', inplace = True)

# %%
df4.isna().sum()
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                           0
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
mean_value = df['reviews_per_month'].median()

# %%
df4['reviews_per_month'].fillna(mean_value, inplace = True)

# %%
df4['host_name'].fillna(df4['host_name'].value_counts().index[0], inplace = True)

# %%
df4.sample(10)
# Out:
#              id                                               name    host_id  \
# 19523  15598303  Cozy Bedroom in cute Clinton Hill brownstone apt!   15055897
# 27346  21581545  STEPS TO LGA, Near CITIFIELD, JFK MANHATTAN(RM 3)  156948703
# 47430  35729594           Rose's Brooklyn Oasis - Close to Subway!  268757078
# 10366   7933400                          Astoria Nice Neighborhood   40336543
# 24997  20017584    Large Room with Private Entrance Close to Metro  142133001
# 29314  22483776                                     THE COOL HOUSE   55197894
# 13714  10293298  Private Room/Private Bath in Gorgeous Brooklyn...   52954055
# 34940  27701535               Place for sleeping and exploring NYC  209121939
# 16982  13497305                     Stunning, Prime, Beautiful NYC    2861768
# 27850  21823574     Quiet and cozy in Queens and close JFK Airport  159088461
#
#             host_name neighbourhood_group       neighbourhood  latitude  \
# ...

# %%
df4.isna().sum()
# Out:
# id                                 0
# name                              16
# host_id                            0
# host_name                          0
# neighbourhood_group                0
# neighbourhood                      0
# latitude                           0
# longitude                          0
# room_type                          0
# price                              0
# minimum_nights                     0
# number_of_reviews                  0
# last_review                        0
# reviews_per_month                  0
# calculated_host_listings_count     0
# availability_365                   0
# dtype: int64

# %%
df4['name'].fillna(df4['name'].value_counts().index[0], inplace = True)

# %%
df4.isna().sum()
# Out:
# id                                0
# name                              0
# host_id                           0
# host_name                         0
# neighbourhood_group               0
# neighbourhood                     0
# latitude                          0
# longitude                         0
# room_type                         0
# price                             0
# minimum_nights                    0
# number_of_reviews                 0
# last_review                       0
# reviews_per_month                 0
# calculated_host_listings_count    0
# availability_365                  0
# dtype: int64
