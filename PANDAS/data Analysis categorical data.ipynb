# %%
import pandas as pd

# %%
df =pd.read_csv('googleplaystore.csv')

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
for i in df['Category'].unique():
    print(i)
# Out:
# ART_AND_DESIGN
# AUTO_AND_VEHICLES
# BEAUTY
# BOOKS_AND_REFERENCE
# BUSINESS
# COMICS
# COMMUNICATION
# DATING
# EDUCATION
# ENTERTAINMENT
# EVENTS
# FINANCE
# FOOD_AND_DRINK
# HEALTH_AND_FITNESS
# HOUSE_AND_HOME
# LIBRARIES_AND_DEMO
# LIFESTYLE
# GAME
# FAMILY
# MEDICAL
# SOCIAL
# SHOPPING
# PHOTOGRAPHY
# SPORTS
# TRAVEL_AND_LOCAL
# TOOLS
# PERSONALIZATION
# PRODUCTIVITY
# PARENTING
# WEATHER
# VIDEO_PLAYERS
# NEWS_AND_MAGAZINES
# MAPS_AND_NAVIGATION
# 1.9

# %% [markdown]
# ## Find the total number of application which is present in art and design

# %%
c = 0
for i in df['Category']:
    if i == 'ART_AND_DESIGN':
        c+=1
print("There are", c,'category in the field of ART and Design')
# Out:
# There are 65 category in the field of ART and Design

# %%
for i in df['Content Rating'].unique():
    print(i)
# Out:
# Everyone
# Teen
# Everyone 10+
# Mature 17+
# Adults only 18+
# Unrated
# nan

# %%
a = 0
for i in df['Content Rating']:
    if i == 'Everyone':
        a+=1
print("There are",a,"number of application where everyone had done the content rating")
# Out:
# There are 8714 number of application where everyone had done the content rating

# %%
df['Type'].unique()
# Out:
# array(['Free', 'Paid', nan, '0'], dtype=object)

# %%
df = df.dropna()

# %%
df['Type'].unique()
# Out:
# array(['Free', 'Paid'], dtype=object)

# %%
c=0
for i in df['Type']:
    if i == 'Free':
        
       c+=1
print('There are', c ,'number of free application in the playstore')
# Out:
# There are 8715 number of free application in the playstore

# %%
c=0
for i in df['Type']:
    if i == 'Paid':
        
       c+=1
print('There are', c ,'number of paid application in the playstore')
# Out:
# There are 645 number of paid application in the playstore

# %%
for i in df['Content Rating'].unique():
    print(i)
# Out:
# Everyone
# Teen
# Everyone 10+
# Mature 17+
# Adults only 18+
# Unrated

# %%
a=0
for i in df['Content Rating']:
    if i == 'Adults only 18+':
        a+=1
print("There are",a,"number of applications which are Adults only and 18+")
t=0
for i in df['Content Rating']:
    if i == 'Teen':
        t+=1
print("There are",t,"number of applications which are for teen")

r =str(a/t)[:7]
print('The ratio of Adults only 18+ application and Teen is',r)
# Out:
# There are 3 number of applications which are Adults only and 18+
# There are 1084 number of applications which are for teen
# The ratio of Adults only 18+ application and Teen is 0.00276

# %%
len(df['Last Updated'].unique())
# Out:
# 1299

# %%
c = 0
for name in df['Last Updated'].unique():
    for i in df['Last Updated']:
        if i == name:
            c+=1
    print(name,":", c)
# Out:
# January 7, 2018 : 5
# January 15, 2018 : 12
# August 1, 2018 : 287
# June 8, 2018 : 322
# June 20, 2018 : 364
# March 26, 2017 : 367
# April 26, 2018 : 391
# June 14, 2018 : 419
# September 20, 2017 : 432
# July 3, 2018 : 512
# October 27, 2017 : 522
# July 31, 2018 : 801
# April 2, 2018 : 813
# June 26, 2018 : 866
# August 3, 2018 : 1185
# November 7, 2017 : 1196
# July 30, 2018 : 1395
# April 20, 2018 : 1408
# March 20, 2018 : 1427
# July 12, 2018 : 1518
# July 7, 2018 : 1542
# April 25, 2018 : 1557
# October 11, 2017 : 1562
# March 21, 2018 : 1572
# August 22, 2017 : 1577
# May 31, 2018 : 1610
# July 19, 2018 : 1726
# January 6, 2018 : 1733
# April 27, 2018 : 1747
# July 11, 2018 : 1843
# August 2, 2018 : 2127
# July 14, 2018 : 2140
# November 29, 2017 : 2151
# March 31, 2018 : 2162
# July 20, 2018 : 2243
# April 15, 2018 : 2248
# January 3, 2018 : 2257
# November 14, 2017 : 2268
# December 17, 2017 : 2271
# May 28, 2018 : 2297
# May 10, 2018 : 2320
# July 26, 2018 : 2466
# ...
