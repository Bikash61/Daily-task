# %%
import pandas as pd
import seaborn as sns

# %%
df = sns.load_dataset('titanic')

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.barplot(x='pclass',y='age',data = df)
# Out:
# <Axes: xlabel='pclass', ylabel='age'>

# %%
sns.barplot(x='embark_town', y='fare',data=df,estimator='sum')
# Out:
# <Axes: xlabel='embark_town', ylabel='fare'>

# %%
sns.barplot(x='pclass',y='fare',data = df,estimator='sum')
# Out:
# <Axes: xlabel='pclass', ylabel='fare'>

# %%
sns.barplot(x='pclass', y= 'fare',hue='sex',data=df,estimator='sum')
# Out:
# <Axes: xlabel='pclass', ylabel='fare'>

# %%
sns.barplot(x='pclass', y= 'fare',hue='sex',data=df)
# Out:
# <Axes: xlabel='pclass', ylabel='fare'>

# %%
sns.boxplot(x='pclass',y='age',data=df)
# Out:
# <Axes: xlabel='pclass', ylabel='age'>

# %%
sns.boxplot(x='class',y='age',hue='survived',data=df)
# Out:
# <Axes: xlabel='class', ylabel='age'>

# %%
sns.violinplot(x='class',y='age',data=df)
# Out:
# <Axes: xlabel='class', ylabel='age'>

# %%
sns.distplot(df['class']==['second']['age'])
# Out:
# <>:1: SyntaxWarning: list indices must be integers or slices, not str; perhaps you missed a comma?
# <>:1: SyntaxWarning: list indices must be integers or slices, not str; perhaps you missed a comma?
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_8612\2933626873.py:1: SyntaxWarning: list indices must be integers or slices, not str; perhaps you missed a comma?
#   sns.distplot(df['class']==['second']['age'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_8612\2933626873.py:1: SyntaxWarning: list indices must be integers or slices, not str; perhaps you missed a comma?
#   sns.distplot(df['class']==['second']['age'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_8612\2933626873.py:1: SyntaxWarning: list indices must be integers or slices, not str; perhaps you missed a comma?
#   sns.distplot(df['class']==['second']['age'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_8612\2933626873.py:1: SyntaxWarning: list indices must be integers or slices, not str; perhaps you missed a comma?
# ...
