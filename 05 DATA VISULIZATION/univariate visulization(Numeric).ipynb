# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('AB_NYC_2019.csv')

# %%
df.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# 0     Private room    149               1                  9  2018-10-19
# 1  Entire home/apt    225               1                 45  2019-05-21
# 2     Private room    150               3                  0         NaN
# 3  Entire home/apt     89               1                270  2019-07-05
# 4  Entire home/apt     80              10                  9  2018-11-19
#
#    reviews_per_month  calculated_host_listings_count  availability_365
# 0               0.21                               6               365
# 1               0.38                               2               355
# 2                NaN                               1               365
# 3               4.64                               1               194
# 4               0.10                               1                 0

# %% [markdown]
# ## Histograms

# %%
sns.histplot(data = df, x = 'price')
# Out:
# <Axes: xlabel='price', ylabel='Count'>

# %%
sns.histplot(data = df[df['price']<1000], x = 'price')
# Out:
# <Axes: xlabel='price', ylabel='Count'>

# %%
sns.histplot(data = df[df['price']<500], x = 'price')
# Out:
# <Axes: xlabel='price', ylabel='Count'>

# %%
sns.histplot(data = df, x = "availability_365")
# Out:
# <Axes: xlabel='availability_365', ylabel='Count'>

# %%
sns.histplot(data = df[df['minimum_nights']<25], x = 'minimum_nights')
# Out:
# <Axes: xlabel='minimum_nights', ylabel='Count'>

# %% [markdown]
# ## Distribution

# %%
sns.distplot(df['price'])
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13020\444587821.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['price'])
# <Axes: xlabel='price', ylabel='Density'>

# %%
sns.distplot(df['availability_365'])
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13020\2842795716.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['availability_365'])
# <Axes: xlabel='availability_365', ylabel='Density'>

# %%
sns.distplot(df['reviews_per_month'])
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13020\4190268020.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['reviews_per_month'])
# <Axes: xlabel='reviews_per_month', ylabel='Density'>

# %% [markdown]
# ## Boxplot

# %%
sns.boxplot(df['price'])
# Out:
# <Axes: ylabel='price'>

# %%
sns.boxplot(df['availability_365'])
# Out:
# <Axes: ylabel='availability_365'>

# %% [markdown]
# ## Titanic Data set

# %%
df2 = sns.load_dataset('titanic')

# %%
df2.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.histplot(data = df2, x = 'fare')
# Out:
# <Axes: xlabel='fare', ylabel='Count'>

# %%
sns.distplot(df2['fare'])
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13020\2415969963.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df2['fare'])
# <Axes: xlabel='fare', ylabel='Density'>

# %%
sns.boxplot(df2['fare'])
# Out:
# <Axes: ylabel='fare'>

# %%
sns.histplot(data = df2, x ='age')
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
sns.distplot(df2['age'])
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13020\3499536833.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df2['age'])
# <Axes: xlabel='age', ylabel='Density'>

# %%
sns.boxplot(df2['age'])
# Out:
# <Axes: ylabel='age'>
